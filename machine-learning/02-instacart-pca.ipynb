# %% [markdown]
# # 案例： 探究用户对物品类别的喜好细分
# 用户                  物品类别
# user_id               aisle
# 1) 需要将user_id 和aisle放在同一个表中 -- 合并
# 2) 找到user_id 和aisle -- 交叉表和透视表
# 3) 特征冗余过多 -- PCA 降维

# %%
import pandas as pd

# %%
orders_products = pd.read_csv('order_products__prior.csv')
products = pd.read_csv('products.csv')
aisles = pd.read_csv('aisles.csv')
orders = pd.read_csv('orders.csv')

# %%
orders_products.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
aisles.head()
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
tab1 = pd.merge(orders_products,pd.merge(aisles, products, on=['aisle_id','aisle_id']), how='left',on=['product_id'])

# %%
tab1.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  aisle_id  \
# 0         2       33120                  1          1        86
# 1         2       28985                  2          1        83
# 2         2        9327                  3          0       104
# 3         2       45918                  4          1        19
# 4         2       30035                  5          0        17
#
#                 aisle           product_name  department_id
# 0                eggs     Organic Egg Whites             16
# 1    fresh vegetables  Michigan Organic Kale              4
# 2   spices seasonings          Garlic Powder             13
# 3       oils vinegars         Coconut Butter             13
# 4  baking ingredients      Natural Sweetener             13

# %%
tab2 = pd.merge(tab1, orders, on=['order_id','order_id'])

# %%
tab3 = pd.crosstab(tab2['user_id'], tab2['aisle'])

# %%
tab3.head()
# Out:
# aisle    air fresheners candles  asian foods  baby accessories  \
# user_id
# 1                             0            0                 0
# 2                             0            3                 0
# 3                             0            0                 0
# 4                             0            0                 0
# 5                             0            2                 0
#
# aisle    baby bath body care  baby food formula  bakery desserts  \
# user_id
# 1                          0                  0                0
# 2                          0                  0                0
# 3                          0                  0                0
# 4                          0                  0                0
# 5                          0                  0                0
#
# aisle    baking ingredients  baking supplies decor  beauty  beers coolers  \
# user_id
# 1                         0                      0       0              0
# ...

# %%
from sklearn.decomposition import PCA

# %%
transformer = PCA(n_components=0.95)
data = transformer.fit_transform(tab3)

# %%
data.shape
# Out:
# (206209, 44)

# %%
data[:5]
# Out:
# array([[-2.42156587e+01,  2.42942720e+00, -2.46636975e+00,
#         -1.45686388e-01,  2.69042476e-01, -1.43293209e+00,
#          2.14067666e+00, -2.73803122e+00, -2.71431623e+00,
#         -1.74313529e+00, -1.13632718e+00,  6.73601069e-01,
#         -1.65070735e+00,  2.83802486e+00, -5.89384489e+00,
#          7.84312891e+00, -4.84010146e+00, -3.22598697e+00,
#         -4.58007571e+00,  7.77403349e-01, -3.69912893e+00,
#          1.90721439e+00,  2.99538594e+00,  7.72922878e-01,
#          6.86800336e-01,  1.69439402e+00, -2.34323022e+00,
#         -1.50209010e+00, -1.77419679e+00,  1.18142221e+00,
#          3.63171145e+00, -2.47197528e+00, -5.83687334e+00,
#          2.33555295e+00, -3.04647865e+00, -1.46497789e+00,
#         -2.41394272e-01, -3.30414071e+00, -1.25065489e+00,
#         -8.20738851e-01, -1.46135513e+00, -8.87771489e-02,
#         -3.80877606e-01,  2.15688310e-01],
#        [ 6.46320806e+00,  3.67511165e+01,  8.38255336e+00,
# ...

# %%
from sklearn.cluster import KMeans

# %%
estimator = KMeans(n_clusters=3)
estimator.fit(data)
# Out:
# KMeans(n_clusters=3)

# %%
y_predict=estimator.predict(data)

# %%
y_predict[0:100]
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 0, 2, 0, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 0, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2,
#        2, 2, 2, 2, 0, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2,
#        0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2])

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette_score(data, y_predict)
# Out:
# 0.5367024543100574
